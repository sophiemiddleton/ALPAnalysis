# %%
import uproot
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.transforms
import matplotlib.lines
import mplhep as hep
import pathlib
import requests
from matplotlib.ticker import MultipleLocator, FormatStrFormatter,AutoMinorLocator
#plt.rcParams['text.usetex'] = True


SMALL_SIZE = 11
MEDIUM_SIZE = 14
BIGGER_SIZE = 16
MUCHBIGGER_SIZE = 22
plt.rc('font', size=BIGGER_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=MUCHBIGGER_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MUCHBIGGER_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=BIGGER_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=BIGGER_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

import pandas as pd

proj_down = pd.read_csv('projections_lower.csv')
proj_down_mass = proj_down['mass']
proj_down_coup = proj_down['coupling']

proj_up = pd.read_csv('projections_upper.csv')
proj_up_mass = proj_up['mass']
proj_up_coup = proj_up['coupling']

argo_data_down = pd.read_csv('limit_upper.csv')
argo_zeros_down = argo_data_down['mass']
argo_zeros_limit_down = argo_data_down['limit']

argo_data_up = pd.read_csv('limit_lower.csv')
argo_zeros_up = argo_data_up['mass']
argo_zeros_limit_up = argo_data_up['limit']

argo_data_top = pd.read_csv('top.csv')
argo_zeros_top= argo_data_top['mass']
argo_zeros_limit_top = argo_data_top['limit']

argo_data_ser= pd.read_csv('zeros.csv')
argo_zeros_ser = argo_data_ser['mass']
argo_zeros_limit_ser = argo_data_ser['limit']

#\def\babar{\mbox{\slshape B\kern-0.1em{\smaller A}\kern-0.1em B\kern-0.1em{\smaller A\kern-0.2em R}}}


#PreLabel = r"Preliminary"
xlabel = r"$m_{ALP}(GeV/c^{2})$"
ylabel = r"$g_{a \gamma} (GeV^{-1})$"
LDMXLogo = r"$\it{LDMX} Internal$"
# load atlas style
plt.style.use(hep.style.ATLAS)

fig, ax = plt.subplots()


ax.tick_params(which='both', width=1, axis='both',grid_alpha=0.5)

# add process label
#ax.text(0.05, 0.5, extralabel, transform = ax.transAxes, va='top')
#ax.text(0.05, 0.4, processLabel, transform = ax.transAxes, va='top')

# add lumi label
# ax.text(0.8, 0.1, PreLabel, transform = ax.transAxes, va='top',fontweight='bold')
# Set up initial legend
leg1_elements = [matplotlib.lines.Line2D([0], [0], color='orange',  label='Already Excluded'), 
                 matplotlib.lines.Line2D([0], [0], color='blue',  label='LDMX Sensitivty')]#,
                 
leg1 = ax.legend(handles=leg1_elements, loc='lower right')

## Axis Labels
ax.set_xlabel(xlabel)
ax.set_ylabel(ylabel)
#ax.set_xscale('log')
ax.set_yscale('log')
# for multiple legends
#ax.legend(loc='upper left', bbox_to_anchor=(0.01, 0.85), handles=leg2_elements, fontsize='small')
ax.add_artist(leg1);

ax.set_ylim([0.00001,0.002])
ax.set_xlim([0.02,0.2])
ax.fill_between(proj_down_mass, proj_up_coup, proj_down_coup,color='blue')
ax.fill_between(argo_zeros_down, argo_zeros_limit_down, argo_zeros_limit_up,color='orange')
ax.fill_between(argo_zeros_top, argo_zeros_limit_top, argo_zeros_limit_ser, color='orange')



#plt.plot(mass, limit_est, '-',c='magenta', linestyle='--',linewidth=1.0)
#plt.plot(mass, limit_av, '-',c='orange', linestyle='--',linewidth=1.0)
#plt.plot(delphi,delphi_limit, '-',c='g',linewidth=1.0)
#plt.plot(BBN,BBN_limit, '-',c='y',linewidth=1.0)

plt.tight_layout()

fig.show()
fig.savefig("LDMXprojection.pdf")
print(ax.yaxis.get_major_formatter())
print(ax.yaxis.get_minor_formatter())
# Out:
# ...
# /var/folders/7n/vm0b0ykd625d2tr7y1r39qgw0000gn/T/ipykernel_54613/2085849912.py:102: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
import uproot
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.transforms
import matplotlib.lines
import mplhep as hep
import pathlib
import requests
from matplotlib.ticker import MultipleLocator, FormatStrFormatter,AutoMinorLocator
#plt.rcParams['text.usetex'] = True


SMALL_SIZE = 11
MEDIUM_SIZE = 14
BIGGER_SIZE = 16
MUCHBIGGER_SIZE = 22
plt.rc('font', size=BIGGER_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=MUCHBIGGER_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MUCHBIGGER_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=BIGGER_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=BIGGER_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

import pandas as pd

proj_down_1e16 = pd.read_csv('projections_lower_1e16.csv')
proj_down_mass_1e16 = proj_down_1e16['mass']
proj_down_coup_1e16 = proj_down_1e16['coupling']

proj_up_1e16 = pd.read_csv('projections_upper_1e16.csv')
proj_up_mass_1e16 = proj_up_1e16['mass']
proj_up_coup_1e16 = proj_up_1e16['coupling']

proj_down_1e14 = pd.read_csv('projections_lower_1e14.csv')
proj_down_mass_1e14 = proj_down_1e14['mass']
proj_down_coup_1e14 = proj_down_1e14['coupling']

proj_up_1e14 = pd.read_csv('projections_upper_1e14.csv')
proj_up_mass_1e14 = proj_up_1e14['mass']
proj_up_coup_1e14 = proj_up_1e14['coupling']


argo_data_down = pd.read_csv('limit_upper.csv')
argo_zeros_down = argo_data_down['mass']
argo_zeros_limit_down = argo_data_down['limit']

argo_data_up = pd.read_csv('limit_lower.csv')
argo_zeros_up = argo_data_up['mass']
argo_zeros_limit_up = argo_data_up['limit']

argo_data_top = pd.read_csv('top.csv')
argo_zeros_top= argo_data_top['mass']
argo_zeros_limit_top = argo_data_top['limit']

argo_data_ser= pd.read_csv('zeros.csv')
argo_zeros_ser = argo_data_ser['mass']
argo_zeros_limit_ser = argo_data_ser['limit']

#\def\babar{\mbox{\slshape B\kern-0.1em{\smaller A}\kern-0.1em B\kern-0.1em{\smaller A\kern-0.2em R}}}


#PreLabel = r"Preliminary"
xlabel = r"$m_{ALP}(GeV)$"
ylabel = r"$g_{a \gamma} (GeV^{-1})$"
LDMXLogo = r"$\it{LDMX} Internal$"
# load atlas style
plt.style.use(hep.style.ATLAS)

fig, ax = plt.subplots()


ax.tick_params(which='both', width=1, axis='both',grid_alpha=0.5)

# add process label
#ax.text(0.05, 0.5, extralabel, transform = ax.transAxes, va='top')
#ax.text(0.05, 0.4, processLabel, transform = ax.transAxes, va='top')

# add lumi label
# ax.text(0.8, 0.1, PreLabel, transform = ax.transAxes, va='top',fontweight='bold')
# Set up initial legend
leg1_elements = [matplotlib.lines.Line2D([0], [0], color='orange',  label='Already Excluded'), 
                 matplotlib.lines.Line2D([0], [0], color='blue',  label='LDMX 90% CL (1e16 EOT) (est.)'),
                matplotlib.lines.Line2D([0], [0], color='green',  label='LDMX 90% CL (4e14 EOT) (est.)')]#,
                 
leg1 = ax.legend(handles=leg1_elements, loc='upper right')

## Axis Labels
ax.set_xlabel(xlabel)
ax.set_ylabel(ylabel)
#ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xscale('log')
# for multiple legends
#ax.legend(loc='upper left', bbox_to_anchor=(0.01, 0.85), handles=leg2_elements, fontsize='small')
ax.add_artist(leg1);
print(proj_down_mass_1e14, proj_up_coup_1e14, proj_down_coup_1e14)
ax.set_ylim([8e-6,0.005])
ax.set_xlim([0.0105,0.2])
ax.fill_between(argo_zeros_down, argo_zeros_limit_down, argo_zeros_limit_up,color='orange')
ax.fill_between(argo_zeros_top, argo_zeros_limit_top, argo_zeros_limit_ser, color='orange')
ax.fill_between(proj_down_mass_1e16, proj_up_coup_1e16, proj_down_coup_1e16,color='blue',alpha=0.2)
ax.fill_between(proj_down_mass_1e14, proj_up_coup_1e14, proj_down_coup_1e14,color='green',alpha=0.2)
plt.tight_layout()

fig.show()
fig.savefig("LDMXprojection.pdf")
print(ax.yaxis.get_major_formatter())
print(ax.yaxis.get_minor_formatter())
# Out:
# 0    0.01
# 1    0.02
# 2    0.03
# 3    0.04
# 4    0.05
# 5    0.06
# Name: mass, dtype: float64 0    0.010000
# 1    0.004193
# 2    0.001460
# 3    0.000675
# 4    0.000346
# 5    0.000160
# Name: coupling, dtype: float64 0    0.000071
# 1    0.000052
# 2    0.000048
# 3    0.000050
# 4    0.000056
# 5    0.000076
# Name: coupling, dtype: float64
# ...
# /var/folders/7n/vm0b0ykd625d2tr7y1r39qgw0000gn/T/ipykernel_18626/2679934637.py:106: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
import uproot
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.transforms
import matplotlib.lines
import mplhep as hep
import pathlib
import requests
from matplotlib.ticker import MultipleLocator, FormatStrFormatter,AutoMinorLocator
#plt.rcParams['text.usetex'] = True


SMALL_SIZE = 11
MEDIUM_SIZE = 14
BIGGER_SIZE = 16
MUCHBIGGER_SIZE = 22
plt.rc('font', size=BIGGER_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=MUCHBIGGER_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MUCHBIGGER_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=BIGGER_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=BIGGER_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

import pandas as pd

proj_down_1e16 = pd.read_csv('projections_lower_1e16_eff.csv')
proj_down_mass_1e16 = proj_down_1e16['mass']
proj_down_coup_1e16 = proj_down_1e16['coupling']

proj_up_1e16 = pd.read_csv('projections_upper_1e16_eff.csv')
proj_up_mass_1e16 = proj_up_1e16['mass']
proj_up_coup_1e16 = proj_up_1e16['coupling']

proj_down_1e14 = pd.read_csv('projections_lower_1e14.csv')
proj_down_mass_1e14 = proj_down_1e14['mass']
proj_down_coup_1e14 = proj_down_1e14['coupling']

proj_up_1e14 = pd.read_csv('projections_upper_1e14.csv')
proj_up_mass_1e14 = proj_up_1e14['mass']
proj_up_coup_1e14 = proj_up_1e14['coupling']


argo_data_down = pd.read_csv('limit_upper.csv')
argo_zeros_down = argo_data_down['mass']
argo_zeros_limit_down = argo_data_down['limit']

argo_data_up = pd.read_csv('limit_lower.csv')
argo_zeros_up = argo_data_up['mass']
argo_zeros_limit_up = argo_data_up['limit']

argo_data_top = pd.read_csv('top.csv')
argo_zeros_top= argo_data_top['mass']
argo_zeros_limit_top = argo_data_top['limit']

argo_data_ser= pd.read_csv('zeros.csv')
argo_zeros_ser = argo_data_ser['mass']
argo_zeros_limit_ser = argo_data_ser['limit']

#\def\babar{\mbox{\slshape B\kern-0.1em{\smaller A}\kern-0.1em B\kern-0.1em{\smaller A\kern-0.2em R}}}


#PreLabel = r"Preliminary"
xlabel = r"$m_{ALP}(GeV/c^{2})$"
ylabel = r"$g_{a \gamma} (GeV^{-1})$"
LDMXLogo = r"$\it{LDMX} Internal$"
# load atlas style
plt.style.use(hep.style.ATLAS)

fig, ax = plt.subplots()


ax.tick_params(which='both', width=1, axis='both',grid_alpha=0.5)

# add process label
#ax.text(0.05, 0.5, extralabel, transform = ax.transAxes, va='top')
#ax.text(0.05, 0.4, processLabel, transform = ax.transAxes, va='top')

# add lumi label
# ax.text(0.8, 0.1, PreLabel, transform = ax.transAxes, va='top',fontweight='bold')
# Set up initial legend
leg1_elements = [matplotlib.lines.Line2D([0], [0], color='orange',  label='Already Excluded'), 
                 matplotlib.lines.Line2D([0], [0], color='blue',  label='LDMX 90% CL (1e16 EOT) '),
                matplotlib.lines.Line2D([0], [0], color='green',  label='LDMX 90% CL (4e14 EOT) ')]#,
                 
leg1 = ax.legend(handles=leg1_elements, loc='center right')

## Axis Labels
ax.set_xlabel(xlabel)
ax.set_ylabel(ylabel)
#ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xscale('log')
# for multiple legends
#ax.legend(loc='upper left', bbox_to_anchor=(0.01, 0.85), handles=leg2_elements, fontsize='small')
ax.add_artist(leg1);
print(proj_down_mass_1e14, proj_up_coup_1e14, proj_down_coup_1e14)
ax.set_ylim([8e-6,0.005])
ax.set_xlim([0.0105,0.2])
ax.fill_between(argo_zeros_down, argo_zeros_limit_down, argo_zeros_limit_up,color='orange')
ax.fill_between(argo_zeros_top, argo_zeros_limit_top, argo_zeros_limit_ser, color='orange')
ax.fill_between(proj_down_mass_1e16, proj_up_coup_1e16, proj_down_coup_1e16,color='blue',alpha=0.2)
ax.fill_between(proj_down_mass_1e14, proj_up_coup_1e14, proj_down_coup_1e14,color='green',alpha=0.2)
plt.tight_layout()

fig.show()
fig.savefig("LDMXprojection_eff.pdf")
print(ax.yaxis.get_major_formatter())
print(ax.yaxis.get_minor_formatter())
# Out:
# 0    0.01
# 1    0.02
# 2    0.03
# 3    0.04
# 4    0.05
# 5    0.06
# Name: mass, dtype: float64 0    0.010000
# 1    0.004193
# 2    0.001460
# 3    0.000675
# 4    0.000346
# 5    0.000160
# Name: coupling, dtype: float64 0    0.000071
# 1    0.000052
# 2    0.000048
# 3    0.000050
# 4    0.000056
# 5    0.000076
# Name: coupling, dtype: float64
# ...
# /var/folders/7n/vm0b0ykd625d2tr7y1r39qgw0000gn/T/ipykernel_18626/88872166.py:106: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
